# %% [markdown]
# # Kết nối PostgreSQL bằng SQLAlchemy
#
# Notebook mẫu để kiểm tra kết nối từ container Jupyter tới PostgreSQL.

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text

DATABASE_URL = os.getenv(
    "DATABASE_URL",
    "postgresql+psycopg2://postgres:postgres@postgres:5432/fashion_dw",
)

engine = create_engine(DATABASE_URL)
DATABASE_URL
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 import pandas as pd
# ----> 3 from sqlalchemy import create_engine, text
#       4
#       5 DATABASE_URL = os.getenv(
#       6     "DATABASE_URL",
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT current_database(), current_user, version();"))
    for row in result:
        print(row)

# %%
schemas = pd.read_sql(
    """
    SELECT schema_name
    FROM information_schema.schemata
    WHERE schema_name IN ('raw', 'staging', 'dwh', 'mart')
    ORDER BY schema_name;
    """,
    engine,
)

schemas

# %%
# Ví dụ đọc bảng raw.customers sau khi bạn đã load CSV vào PostgreSQL.
# customers_df = pd.read_sql("SELECT * FROM raw.customers LIMIT 10;", engine)
# customers_df.head()
